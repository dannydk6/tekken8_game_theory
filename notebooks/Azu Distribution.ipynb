# %%
from tekken8_game_theory.xlsx import create_excel_file

# %%
import os
os.listdir('../data/azucena/artifacts')
# Out:
# ['azucena_heat_engager_plus17.gbt',
#  'azu_12bplus8_reina_v2.gbt',
#  'azu_BT-5_reina.gbt',
#  'azu_bt1_reina.gbt',
#  'azu_db3_BTplus4_reina.gbt',
#  'azu_df1.gbt',
#  'azu_lib_plus8.gbt']

# %%
os.listdir('../data/azucena')
# Out:
# ['artifacts', 'inputs', 'json2gbt.py', 'output']

# %%
create_excel_file("azucena_gto.xlsx", 
                  input_dir='../data/azucena/artifacts', 
                  output_dir="../data/azucena/output", 
                  precision=0, 
                  drop_zeros=True)
# Out:
# [{'df':     player strategy  distribution  strategy_value
#   0  Azucena    ff3+4      0.368421              14
#   1  Azucena      db3      0.631579              14
#   2    Reina        B      0.894737             -14
#   3    Reina       DB      0.105263             -14,
#   'metadata': {'P1': 'Azucena',
#    'P2': 'Reina',
#    'Payoff': 13.8,
#    'Comment': 'Azucena Heat Engager (+17). May need to look at d1+2 oki.'}},
#  {'df':     player   strategy  distribution  strategy_value
#   0  Azucena       BT.3      0.269560               6
#   1  Azucena    BT.2(2)      0.468183               6
#   2  Azucena        qcb      0.262257               6
#   3    Reina          B      0.774463              -6
#   4    Reina   Hop Kick      0.091175              -6
#   5    Reina  Low Parry      0.134363              -6,
#   'metadata': {'P1': 'Azucena',
#    'P2': 'Reina',
#    'Payoff': 6.2,
#    'Comment': 'Azucena 1,2~B BT (+8) on Reina'}},
# ...
