# %%
from tekken8_game_theory.xlsx import full_run

base_path = "../data/reina"

full_run("reina_gto.xlsx", 
         f"{base_path}/inputs",
         f"{base_path}/artifacts",
         output_dir=f"{base_path}/output", 
         precision=0, 
         drop_zeros=True)
# Out:
# [{'df':    player strategy  distribution  strategy_value
#   0  Reina1    SEN.2      0.653233               5
#   1  Reina1    SEN.4      0.159325               5
#   2  Reina1  SEN.3+4      0.187441               5
#   3  Reina2        B      0.424141              -5
#   4  Reina2       DB      0.164324              -5
#   5  Reina2    SSL~b      0.097626              -5
#   6  Reina2   B~wait      0.313910              -5,
#   'metadata': {'P1': 'Reina1',
#    'P2': 'Reina2',
#    'Payoff': 5.2,
#    'Comment': 'can also be used for f2,3 on hit into SEN'}},
#  {'df':    player      strategy  distribution  strategy_value
#   0  Reina1         SEN.3      0.345774              -5
#   1  Reina1         SEN.2      0.389493              -5
#   2  Reina1       SEN.1+2      0.264733              -5
#   3  Reina2            DB      0.275383               5
#   4  Reina2  SSL~b~punish      0.287214               5
#   5  Reina2  SSR~b~punish      0.437403               5,
#   'metadata': {'P1': 'Reina1',
#    'P2': 'Reina2',
#    'Payoff': -5.0,
#    'Comment': 'The ubiquitous f,F+2,F mixup on block, in the mirror'}}]
