# %%
import json
import os
import pandas as pd

def full_path(gbt_filename, base_path=None):
    return gbt_filename if base_path is None else f"{base_path}/{gbt_filename}"

def json_to_excel(filename, base_path=None, output_dir=None):
    scenario_file = full_path(filename, base_path)
    
    # Set path for .json converted file based on output_dir
    out_file = scenario_file.replace('.json', '.xlsx')
    #out_path = f'{output_dir}/{out_file}'
    
    with open(scenario_file, 'r') as f:
        js = json.load(f)
        
    print(js)
    
    sheet1 = [{'key': 'title', 'value': js['title']},
              {'key': 'P1', 'value': js['P1']},
              {'key': 'P2', 'value': js['P2']},
              {'key': 'comment', 'value': js['comment']}]
    sheet1 = pd.DataFrame(sheet1)
    
    print(sheet1)
    
    sheet2 = js['payoffs']
    sheet2 = pd.DataFrame(js['payoffs'])
    sheet2.columns = js['P2-strats']
    sheet2.index  =js['P1-strats']
    sheet2 = sheet2.reset_index()
    sheet2.rename(columns={'index': 'strats'}, inplace=True)
    
    sheet1.to_excel(out_file, sheet_name='Metadata')
    sheet2.to_excel(out_file, sheet_name='Payoffs')
    return sheet2

# %%
base_path = '../data/azucena/inputs'
filename = 'azu_db3_BTplus4_reina.json'

# %%
#Dangerous operation
#json_to_excel(filename, base_path,output_dir = '../')
# Out:
# {'title': 'Azucena db3 (+4) into BT on Reina', 'P1': 'Azucena', 'P2': 'Reina', 'P1-strats': ['BT.1', 'BT.1,2', 'BT.1,4', 'BT.1+2', 'BT.3', 'BT.1+3', 'BT.4', 'BT.2(2)', 'BT.4,3', 'BT.3+4', 'B (exit)', 'qcb', 'd1'], 'P2-strats': ['B', 'DB', '112', 'DB1', 'SSR~b', 'SSL~b', 'Power Crush', 'Hop Kick', 'Low Parry'], 'comment': 'Azucena db3 (+4) into BT on Reina. BT4, BT.4,3 requires upstream recalculation on change', 'payoffs': [[-0.22, -76, 10, -5, -23, 10, 10, 10, 0], [-23.52, -76, 33, -5, -23, 32, 33, 33, -76], [-0.22, -76, 31, -5, -23, 30, 31, 31, 21], [-23, 17, 73, 67, 17, 17, -6, 14, 17], [23, -34, -24, -6, 23, 23, 41, -64, -43], [0, -76, 0, -5, -76, 0, 35, -64, -76], [-5.68, 15, -24, -6, 15, 15, -8, 52, 15], [0, 38, -24, -6, -75, 15, -8, 12, 38], [-43, 36, -24, -6, 36, 36, 13, 44, 36], [0, 0, -38, 81, -76, 76, -28, -64, 0], [0, 0, 0, 0, 0, 0, 31.83, 31.83, 0], [0, 0, 68, 0, 0, 0, 31.83, 68, 0], [0, 0, 6, 6, 6, 6, 6, 6, -43]]}
#        key                                              value
# 0    title                  Azucena db3 (+4) into BT on Reina
# 1       P1                                            Azucena
# 2       P2                                              Reina
# 3  comment  Azucena db3 (+4) into BT on Reina. BT4, BT.4,3...
#       strats      B  DB  112  DB1  SSR~b  SSL~b  Power Crush  Hop Kick  \
# 0       BT.1  -0.22 -76   10   -5    -23     10        10.00     10.00
# 1     BT.1,2 -23.52 -76   33   -5    -23     32        33.00     33.00
# 2     BT.1,4  -0.22 -76   31   -5    -23     30        31.00     31.00
# 3     BT.1+2 -23.00  17   73   67     17     17        -6.00     14.00
# 4       BT.3  23.00 -34  -24   -6     23     23        41.00    -64.00
# 5     BT.1+3   0.00 -76    0   -5    -76      0        35.00    -64.00
# 6       BT.4  -5.68  15  -24   -6     15     15        -8.00     52.00
# 7    BT.2(2)   0.00  38  -24   -6    -75     15        -8.00     12.00
# 8     BT.4,3 -43.00  36  -24   -6     36     36        13.00     44.00
# 9     BT.3+4   0.00   0  -38   81    -76     76       -28.00    -64.00
# 10  B (exit)   0.00   0    0    0      0      0        31.83     31.83
# 11       qcb   0.00   0   68    0      0      0        31.83     68.00
# 12        d1   0.00   0    6    6      6      6         6.00      6.00
#
#     Low Parry
# 0           0
# 1         -76
# 2          21
# 3          17
# 4         -43
# 5         -76
# 6          15
# 7          38
# 8          36
# 9           0
# 10          0
# 11          0
# 12        -43
